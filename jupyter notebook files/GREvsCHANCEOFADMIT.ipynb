# %%
import os
os.getcwd()
os.chdir("C:/Users/syed sarfaraz/Desktop/ML Industry Projects")
os.getcwd()
# Out:
# 'C:\\Users\\syed sarfaraz\\Desktop\\ML Industry Projects'

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
data=pd.read_csv('university-admission-prediction.csv')
data
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0             1        337          118                  4  4.5   4.5  9.65
# 1             2        324          107                  4  4.0   4.5  8.87
# 2             3        316          104                  3  3.0   3.5  8.00
# 3             4        322          110                  3  3.5   2.5  8.67
# 4             5        314          103                  2  2.0   3.0  8.21
# 5             6        330          115                  5  4.5   3.0  9.34
# 6             7        321          109                  3  3.0   4.0  8.20
# 7             8        308          101                  2  3.0   4.0  7.90
# 8             9        302          102                  1  2.0   1.5  8.00
# 9            10        323          108                  3  3.5   3.0  8.60
# 10           11        325          106                  3  3.5   4.0  8.40
# ...

# %%
data.cov()
# Out:
#                      Serial No.   GRE Score  TOEFL Score  University Rating  \
# Serial No.         20875.000000 -169.458918  -124.511022         -11.175351
# GRE Score           -169.458918  127.580377    56.825026           8.206605
# TOEFL Score         -124.511022   56.825026    36.989114           4.519150
# University Rating    -11.175351    8.206605     4.519150           1.307619
# SOP                  -19.666333    6.867206     3.883960           0.825014
# LOR                   -0.493988    5.484521     3.048168           0.644112
# CGPA                  -6.491703    5.641944     2.981607           0.487761
# Research              -0.382766    3.162004     1.411303           0.242645
# Chance of Adm.         0.173437    1.291862     0.680046           0.111384
#
#                          SOP      LOR       CGPA  Research  Chance of Adm.
# Serial No.        -19.666333 -0.493988 -6.491703 -0.382766         0.173437
# ...

# %%
data.corr()
# Out:
#                    Serial No.  GRE Score  TOEFL Score  University Rating  \
# Serial No.           1.000000  -0.103839    -0.141696          -0.067641
# GRE Score           -0.103839   1.000000     0.827200           0.635376
# TOEFL Score         -0.141696   0.827200     1.000000           0.649799
# University Rating   -0.067641   0.635376     0.649799           1.000000
# SOP                 -0.137352   0.613498     0.644410           0.728024
# LOR                 -0.003694   0.524679     0.541563           0.608651
# CGPA                -0.074289   0.825878     0.810574           0.705254
# Research            -0.005332   0.563398     0.467012           0.427047
# Chance of Adm.       0.008505   0.810351     0.792228           0.690132
#
#                         SOP      LOR       CGPA  Research  Chance of Adm.
# Serial No.        -0.137352 -0.003694 -0.074289 -0.005332         0.008505
# GRE Score          0.613498  0.524679  0.825878  0.563398         0.810351
# ...

# %%
gre=data['GRE Score']
gre
# Out:
# 0      337
# 1      324
# 2      316
# 3      322
# 4      314
# 5      330
# 6      321
# 7      308
# 8      302
# 9      323
# 10     325
# 11     327
# 12     328
# 13     307
# 14     311
# 15     314
# 16     317
# 17     319
# 18     318
# 19     303
# 20     312
# 21     325
# 22     328
# 23     334
# 24     336
# 25     340
# 26     322
# 27     298
# 28     295
# 29     310
#       ...
# 470    320
# 471    311
# 472    327
# 473    316
# 474    308
# 475    300
# 476    304
# 477    309
# 478    318
# 479    325
# 480    321
# 481    323
# 482    328
# 483    304
# 484    317
# 485    311
# 486    319
# 487    327
# 488    322
# 489    302
# 490    307
# 491    297
# 492    298
# 493    300
# 494    301
# 495    332
# 496    337
# 497    330
# 498    312
# 499    327
# Name: GRE Score, Length: 500, dtype: int64

# %%
admit=data.iloc[:,8]
admit
# Out:
# 0      0.92
# 1      0.76
# 2      0.72
# 3      0.80
# 4      0.65
# 5      0.90
# 6      0.75
# 7      0.68
# 8      0.50
# 9      0.45
# 10     0.52
# 11     0.84
# 12     0.78
# 13     0.62
# 14     0.61
# 15     0.54
# 16     0.66
# 17     0.65
# 18     0.63
# 19     0.62
# 20     0.64
# 21     0.70
# 22     0.94
# 23     0.95
# 24     0.97
# 25     0.94
# 26     0.76
# 27     0.44
# 28     0.46
# 29     0.54
#        ...
# 470    0.87
# 471    0.64
# 472    0.90
# 473    0.67
# 474    0.67
# 475    0.59
# 476    0.62
# 477    0.65
# 478    0.71
# 479    0.79
# 480    0.80
# 481    0.78
# 482    0.83
# 483    0.71
# 484    0.73
# 485    0.70
# 486    0.68
# 487    0.79
# 488    0.76
# 489    0.65
# 490    0.67
# 491    0.54
# 492    0.53
# 493    0.62
# 494    0.68
# 495    0.87
# 496    0.96
# 497    0.93
# 498    0.73
# 499    0.84
# Name: Chance of Adm. , Length: 500, dtype: float64

# %%
import statsmodels.api as sm
model=sm.OLS(admit,gre).fit() #output,input
model.summary()
# Out:
# C:\Users\syed sarfaraz\Anaconda3\lib\site-packages\statsmodels\compat\pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:        Chance of Adm.    R-squared:                       0.973
# Model:                            OLS   Adj. R-squared:                  0.973
# Method:                 Least Squares   F-statistic:                 1.792e+04
# Date:                Fri, 31 May 2019   Prob (F-statistic):               0.00
# Time:                        23:40:17   Log-Likelihood:                 346.32
# No. Observations:                 500   AIC:                            -690.6
# Df Residuals:                     499   BIC:                            -686.4
# Df Model:                           1
# ...

# %%
import seaborn as sns
sns.pairplot(data)

# %%
corr=data.corr()
sns.heatmap(corr,xticklabels=corr.columns,yticklabels=corr.columns)

# %%
sns.distplot(gre)

# %%
sns.distplot(admit)

# %%
x=gre
x
# Out:
# 0      337
# 1      324
# 2      316
# 3      322
# 4      314
# 5      330
# 6      321
# 7      308
# 8      302
# 9      323
# 10     325
# 11     327
# 12     328
# 13     307
# 14     311
# 15     314
# 16     317
# 17     319
# 18     318
# 19     303
# 20     312
# 21     325
# 22     328
# 23     334
# 24     336
# 25     340
# 26     322
# 27     298
# 28     295
# 29     310
#       ...
# 470    320
# 471    311
# 472    327
# 473    316
# 474    308
# 475    300
# 476    304
# 477    309
# 478    318
# 479    325
# 480    321
# 481    323
# 482    328
# 483    304
# 484    317
# 485    311
# 486    319
# 487    327
# 488    322
# 489    302
# 490    307
# 491    297
# 492    298
# 493    300
# 494    301
# 495    332
# 496    337
# 497    330
# 498    312
# 499    327
# Name: GRE Score, Length: 500, dtype: int64

# %%
y=admit
y
# Out:
# 0      0.92
# 1      0.76
# 2      0.72
# 3      0.80
# 4      0.65
# 5      0.90
# 6      0.75
# 7      0.68
# 8      0.50
# 9      0.45
# 10     0.52
# 11     0.84
# 12     0.78
# 13     0.62
# 14     0.61
# 15     0.54
# 16     0.66
# 17     0.65
# 18     0.63
# 19     0.62
# 20     0.64
# 21     0.70
# 22     0.94
# 23     0.95
# 24     0.97
# 25     0.94
# 26     0.76
# 27     0.44
# 28     0.46
# 29     0.54
#        ...
# 470    0.87
# 471    0.64
# 472    0.90
# 473    0.67
# 474    0.67
# 475    0.59
# 476    0.62
# 477    0.65
# 478    0.71
# 479    0.79
# 480    0.80
# 481    0.78
# 482    0.83
# 483    0.71
# 484    0.73
# 485    0.70
# 486    0.68
# 487    0.79
# 488    0.76
# 489    0.65
# 490    0.67
# 491    0.54
# 492    0.53
# 493    0.62
# 494    0.68
# 495    0.87
# 496    0.96
# 497    0.93
# 498    0.73
# 499    0.84
# Name: Chance of Adm. , Length: 500, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.4,random_state=1)

# %%
x_train
# Out:
# 373    321
# 447    320
# 343    305
# 208    305
# 88     314
# 462    307
# 131    303
# 124    301
# 174    321
# 414    321
# 191    323
# 14     311
# 397    330
# 245    328
# 123    308
# 138    326
# 111    321
# 51     312
# 112    301
# 9      323
# 19     303
# 16     317
# 428    316
# 0      337
# 349    313
# 105    316
# 275    322
# 400    304
# 482    328
# 433    316
#       ...
# 68     318
# 50     313
# 398    312
# 413    317
# 156    315
# 252    318
# 395    324
# 468    323
# 402    324
# 357    301
# 254    321
# 276    329
# 178    309
# 281    317
# 390    314
# 237    329
# 71     336
# 460    319
# 129    333
# 144    325
# 448    312
# 335    325
# 133    323
# 203    334
# 393    317
# 255    307
# 72     321
# 396    325
# 235    326
# 37     300
# Name: GRE Score, Length: 300, dtype: int64

# %%
x_test
# Out:
# 304    313
# 340    312
# 47     339
# 67     316
# 479    325
# 485    311
# 310    320
# 31     327
# 249    321
# 90     318
# 322    314
# 168    293
# 119    327
# 66     327
# 305    321
# 189    324
# 434    306
# 289    313
# 142    331
# 146    315
# 293    312
# 312    311
# 311    328
# 492    298
# 65     325
# 374    315
# 34     331
# 342    308
# 173    323
# 201    315
#       ...
# 27     298
# 89     316
# 388    296
# 73     314
# 185    327
# 171    334
# 161    298
# 69     328
# 218    324
# 91     299
# 270    306
# 420    299
# 378    303
# 125    300
# 370    310
# 274    315
# 59     311
# 120    335
# 12     328
# 386    302
# 224    305
# 236    325
# 499    327
# 314    305
# 157    309
# 364    313
# 186    317
# 267    314
# 230    313
# 407    298
# Name: GRE Score, Length: 200, dtype: int64

# %%
y_train
# Out:
# 373    0.79
# 447    0.84
# 343    0.59
# 208    0.64
# 88     0.64
# 462    0.62
# 131    0.77
# 124    0.57
# 174    0.87
# 414    0.72
# 191    0.87
# 14     0.61
# 397    0.91
# 245    0.81
# 123    0.61
# 138    0.80
# 111    0.69
# 51     0.56
# 112    0.62
# 9      0.45
# 19     0.62
# 16     0.66
# 428    0.69
# 0      0.92
# 349    0.62
# 105    0.69
# 275    0.78
# 400    0.63
# 482    0.83
# 433    0.71
#        ...
# 68     0.68
# 50     0.76
# 398    0.67
# 413    0.49
# 156    0.70
# 252    0.71
# 395    0.82
# 468    0.81
# 402    0.78
# 357    0.68
# 254    0.85
# 276    0.89
# 178    0.72
# 281    0.80
# 390    0.64
# 237    0.86
# 71     0.96
# 460    0.77
# 129    0.92
# 144    0.80
# 448    0.80
# 335    0.83
# 133    0.79
# 203    0.97
# 393    0.77
# 255    0.79
# 72     0.93
# 396    0.84
# 235    0.88
# 37     0.58
# Name: Chance of Adm. , Length: 300, dtype: float64

# %%
y_test
# Out:
# 304    0.62
# 340    0.75
# 47     0.89
# 67     0.57
# 479    0.79
# 485    0.70
# 310    0.76
# 31     0.74
# 249    0.77
# 90     0.64
# 322    0.72
# 168    0.64
# 119    0.71
# 66     0.61
# 305    0.74
# 189    0.88
# 434    0.64
# 289    0.79
# 142    0.92
# 146    0.75
# 293    0.64
# 312    0.78
# 311    0.84
# 492    0.53
# 65     0.55
# 374    0.39
# 34     0.94
# 342    0.58
# 173    0.89
# 201    0.72
#        ...
# 27     0.44
# 89     0.74
# 388    0.49
# 73     0.84
# 185    0.89
# 171    0.89
# 161    0.53
# 69     0.78
# 218    0.84
# 91     0.38
# 270    0.72
# 420    0.42
# 378    0.56
# 125    0.64
# 370    0.72
# 274    0.58
# 59     0.42
# 120    0.94
# 12     0.78
# 386    0.46
# 224    0.67
# 236    0.85
# 499    0.84
# 314    0.66
# 157    0.65
# 364    0.77
# 186    0.84
# 267    0.73
# 230    0.73
# 407    0.58
# Name: Chance of Adm. , Length: 200, dtype: float64

# %%
x_train=x_train.reshape((-1,1))
x_train
# Out:
# C:\Users\syed sarfaraz\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   """Entry point for launching an IPython kernel.
# array([[321],
#        [320],
#        [305],
#        [305],
#        [314],
#        [307],
#        [303],
#        [301],
#        [321],
#        [321],
#        [323],
#        [311],
#        [330],
#        [328],
#        [308],
#        [326],
#        [321],
#        [312],
#        [301],
#        [323],
#        [303],
#        [317],
#        [316],
#        [337],
#        [313],
#        [316],
#        [322],
#        [304],
#        [328],
#        [316],
#        [325],
#        [332],
#        [317],
#        [294],
#        [332],
#        [304],
#        [334],
#        [316],
#        [305],
#        [317],
#        [313],
#        [316],
#        [315],
#        [331],
#        [320],
#        [320],
#        [320],
# ...

# %%
x_test=x_test.reshape((-1,1))
x_test
# Out:
# C:\Users\syed sarfaraz\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   """Entry point for launching an IPython kernel.
# array([[313],
#        [312],
#        [339],
#        [316],
#        [325],
#        [311],
#        [320],
#        [327],
#        [321],
#        [318],
#        [314],
#        [293],
#        [327],
#        [327],
#        [321],
#        [324],
#        [306],
#        [313],
#        [331],
#        [315],
#        [312],
#        [311],
#        [328],
#        [298],
#        [325],
#        [315],
#        [331],
#        [308],
#        [323],
#        [315],
#        [307],
#        [323],
#        [304],
#        [331],
#        [316],
#        [326],
#        [320],
#        [314],
#        [315],
#        [334],
#        [299],
#        [311],
#        [318],
#        [333],
#        [327],
#        [297],
#        [317],
# ...

# %%
from sklearn import linear_model as lm
model=lm.LinearRegression()
result=model.fit(x_train,y_train)

# %%
accuracy=model.score(x_train,y_train)
print('Accuracy of the model:',accuracy)
# Out:
# Accuracy of the model: 0.6467955700462209

# %%
#print coeffecients
print('intercept:',model.intercept_)
print('slope:',model.coef_)
# Out:
# intercept: -2.271681059518437
# slope: [0.0094781]

# %%
predictions=model.predict(x_test)
print('Admit:',predictions,sep='\n')
# Out:
# Admit:
# [0.69496409 0.68548599 0.94139467 0.72339838 0.80870128 0.67600789
#  0.76131078 0.82765748 0.77078888 0.74235458 0.70444219 0.5054021
#  0.82765748 0.82765748 0.77078888 0.79922318 0.62861739 0.69496409
#  0.86556988 0.71392028 0.68548599 0.67600789 0.83713558 0.55279259
#  0.80870128 0.71392028 0.86556988 0.64757359 0.78974508 0.71392028
#  0.63809549 0.78974508 0.60966119 0.86556988 0.72339838 0.81817938
#  0.76131078 0.70444219 0.71392028 0.89400418 0.56227069 0.67600789
#  0.74235458 0.88452608 0.82765748 0.54331449 0.73287648 0.71392028
#  0.78026698 0.70444219 0.84661368 0.86556988 0.85609178 0.64757359
#  0.71392028 0.60966119 0.68548599 0.65705169 0.75183268 0.74235458
#  0.56227069 0.75183268 0.79922318 0.85609178 0.90348227 0.64757359
#  0.76131078 0.79922318 0.95087277 0.74235458 0.61913929 0.71392028
#  0.81817938 0.66652979 0.93191657 0.60966119 0.87504798 0.78974508
#  0.76131078 0.70444219 0.82765748 0.4769678  0.90348227 0.82765748
# ...

# %%
plt.scatter(y_test,predictions)

# %%
y_pred=model.intercept_+model.coef_*x_test
print('predicted response:',y_pred,sep='\n')
# Out:
# predicted response:
# [[0.69496409]
#  [0.68548599]
#  [0.94139467]
#  [0.72339838]
#  [0.80870128]
#  [0.67600789]
#  [0.76131078]
#  [0.82765748]
#  [0.77078888]
#  [0.74235458]
#  [0.70444219]
#  [0.5054021 ]
#  [0.82765748]
#  [0.82765748]
#  [0.77078888]
#  [0.79922318]
#  [0.62861739]
#  [0.69496409]
#  [0.86556988]
#  [0.71392028]
#  [0.68548599]
#  [0.67600789]
#  [0.83713558]
#  [0.55279259]
#  [0.80870128]
#  [0.71392028]
#  [0.86556988]
#  [0.64757359]
#  [0.78974508]
#  [0.71392028]
#  [0.63809549]
#  [0.78974508]
#  [0.60966119]
#  [0.86556988]
#  [0.72339838]
#  [0.81817938]
#  [0.76131078]
#  [0.70444219]
#  [0.71392028]
#  [0.89400418]
#  [0.56227069]
#  [0.67600789]
#  [0.74235458]
#  [0.88452608]
#  [0.82765748]
#  [0.54331449]
#  [0.73287648]
#  [0.71392028]
#  [0.78026698]
#  [0.70444219]
#  [0.84661368]
#  [0.86556988]
#  [0.85609178]
#  [0.64757359]
#  [0.71392028]
#  [0.60966119]
#  [0.68548599]
#  [0.65705169]
#  [0.75183268]
#  [0.74235458]
#  [0.56227069]
# ...

# %%
from sklearn.metrics import mean_squared_error,r2_score
x_train=x_train.reshape((-1,1))
y_train_prediction=model.predict(x_train)
x_test=x_test.reshape(-1,1)
y_test_prediction=model.predict(x_test)

# %%
rmse_training=(np.sqrt(mean_squared_error(y_train,y_train_prediction)))
r2_training=r2_score(y_train,y_train_prediction)
print('the model performance on training set')
print('----------------')
print('rmse is {}'.format(rmse_training))
print("r2 score is {}".format(r2_training))
print('\n') #training set
# Out:
# the model performance on training set
# ----------------
# rmse is 0.07871845132939122
# r2 score is 0.6467955700462209

# %%
#model evaluation for testing set 
rmse_testing=(np.sqrt(mean_squared_error(y_test,y_test_prediction)))
r2_testing=r2_score(y_test,y_test_prediction)
print('the model performance on testing set')
print('----------------')
print('rmse is {}'.format(rmse_testing))
print("r2 score is {}".format(r2_testing))
print('\n')
# Out:
# the model performance on testing set
# ----------------
# rmse is 0.08942558708770272
# r2 score is 0.6536539809549169

# %%
xnew=[[300]]
ynew=model.predict(xnew)
print('GRE Score=%s,Chance of Admit=%s'%(xnew,ynew))
# Out:
# GRE Score=[[300]],Chance of Admit=[0.57174879]

# %%
xnew=[[320]]
ynew=model.predict(xnew)
print('GRE Score=%s,Chance of Admit=%s'%(xnew,ynew))
# Out:
# GRE Score=[[320]],Chance of Admit=[0.76131078]

# %%
plt.scatter(x,y)
plt.xlabel('GRE SCORE')
plt.ylabel('CHANCE OF ADMIT')
# Out:
# Text(0,0.5,'CHANCE OF ADMIT')

# %%
x=x.reshape(-1,1)
y_predicted=model.predict(x)
plt.plot(x,y_predicted,color='y')
plt.show()
# Out:
# C:\Users\syed sarfaraz\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   """Entry point for launching an IPython kernel.
