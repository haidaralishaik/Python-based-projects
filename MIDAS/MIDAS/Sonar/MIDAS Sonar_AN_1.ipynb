# %%
from sklearn.preprocessing import MinMaxScaler
import numpy as np
import pandas as pd
import tensorflow as tf
import MIDASpy as md
import math

# %%
column_names=['column 1','column 2','column 3','column 4','column 5','column 6','column 7','column 8','column 9','column 10']
df=pd.read_excel(r'C:\Users\Jaber Shahnawaz\Downloads\Incomplete Datasets\Incomplete Datasets Without Labels\Sonar\Sonar_AN_1.xlsx.', header=None,names=column_names)
df
# Out:
#                                                                                                                                                                                                                                                                                                                                                                column 1  \
# 0.0200 0.0371 0.0428 0.0207 0.0954 0.0986 0.1539 0.1601 0.3109 0.2111 0.1609 0.1582 0.2238 0.0645 0.0660 0.2273 0.3100 0.2999 0.5078 0.4797 0.5783 0.5071 0.4328 0.5550 0.6711 0.6415 0.7104 0.8080 0.6791 0.3857 0.1307 0.2604 0.5121 0.7547 0.8537 0.8507 0.6692 0.6097 0.4943 0.2744 0.0510 0.2834 0.2825 0.4256 0.2641 0.1386 0.1051 0.1343 0.0383 0.0324    0.0232
# ...

# %%
print('dataType',end='\t')
print('column_names',end='\t')
print('Number of Nulls')
for name in column_names:
    print(df[name].dtype,end='\t\t')
    print(name,end='\t')
    print(df[name].isnull().sum())
# Out:
# dataType	column_names	Number of Nulls
# float64		column 1	0
# float64		column 2	0
# float64		column 3	0
# float64		column 4	0
# float64		column 5	0
# float64		column 6	0
# float64		column 7	0
# float64		column 8	0
# float64		column 9	0
# float64		column 10	0

# %%
df.describe()
# Out:
#          column 1    column 2    column 3    column 4    column 5    column 6  \
# count  208.000000  208.000000  208.000000  208.000000  208.000000  208.000000
# mean     0.016069    0.013420    0.010709    0.010941    0.009290    0.008222
# std      0.012008    0.009634    0.007060    0.007301    0.007088    0.005736
# min      0.000000    0.000800    0.000500    0.001000    0.000600    0.000400
# 25%      0.008425    0.007275    0.005075    0.005375    0.004150    0.004400
# 50%      0.013900    0.011400    0.009550    0.009300    0.007500    0.006850
# 75%      0.020825    0.016725    0.014900    0.014500    0.012100    0.010575
# max      0.100400    0.070900    0.039000    0.035200    0.044700    0.039400
#
#          column 7    column 8    column 9   column 10
# count  208.000000  208.000000  208.000000  208.000000
# mean     0.007820    0.007949    0.007941    0.006507
# std      0.005785    0.006470    0.006181    0.005031
# ...

# %%
df.boxplot(return_type='axes', figsize=(15,5))
# Out:
# <AxesSubplot:>

# %%
df.mean()
# Out:
# column 1     0.016069
# column 2     0.013420
# column 3     0.010709
# column 4     0.010941
# column 5     0.009290
# column 6     0.008222
# column 7     0.007820
# column 8     0.007949
# column 9     0.007941
# column 10    0.006507
# dtype: float64

# %%
corr=df.corr()
corr
# Out:
#            column 1  column 2  column 3  column 4  column 5  column 6  \
# column 1   1.000000  0.627038  0.330396  0.384052  0.278935  0.209752
# column 2   0.627038  1.000000  0.540414  0.343190  0.337581  0.203121
# column 3   0.330396  0.540414  1.000000  0.412337  0.315656  0.421588
# column 4   0.384052  0.343190  0.412337  1.000000  0.455059  0.397378
# column 5   0.278935  0.337581  0.315656  0.455059  1.000000  0.429948
# column 6   0.209752  0.203121  0.421588  0.397378  0.429948  1.000000
# column 7   0.191407  0.191264  0.308197  0.361443  0.387204  0.515154
# column 8   0.325665  0.309673  0.370764  0.404117  0.503465  0.463659
# column 9   0.317942  0.298711  0.346095  0.447118  0.453658  0.430804
# column 10  0.246764  0.195379  0.280780  0.283471  0.264399  0.349449
#
#            column 7  column 8  column 9  column 10
# column 1   0.191407  0.325665  0.317942   0.246764
# column 2   0.191264  0.309673  0.298711   0.195379
# ...

# %%
tf.compat.v1.reset_default_graph()
import tensorflow.compat.v1 as tf
tf.reset_default_graph()

# %%
imputer = md.Midas(layer_structure = [10,10+56,10+56+56,10+56+56+56,10+56+56,10+56,10], vae_layer = False, seed = 560)
imputer.build_model(df)
imputer.train_model(training_epochs=100)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\JABERS~1\AppData\Local\Temp/ipykernel_6756/3542142177.py in <module>
#       1 imputer = md.Midas(layer_structure = [10,10+56,10+56+56,10+56+56+56,10+56+56,10+56,10], vae_layer = False, seed = 560)
# ----> 2 imputer.build_model(df)
#       3 imputer.train_model(training_epochs=100)
#
# ~\anacondanew\lib\site-packages\MIDASpy\midas_base.py in build_model(self, imputation_target, binary_columns, softmax_columns, unsorted, additional_data, verbose)
#     358       raise TypeError("Input data must be in a DataFrame")
#     359     if imputation_target.isnull().sum().sum() == 0:
# --> 360       raise ValueError("Imputation target contains no missing values. Please"\
#     361                        " ensure missing values are encoded as type np.nan")
#     362     self.original_columns = imputation_target.columns
#
# ...

# %%
imputations=imputer.generate_samples(m=15).output_list
np.shape(imputations[-1])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Users\JABERS~1\AppData\Local\Temp/ipykernel_6756/2956739537.py in <module>
# ----> 1 imputations=imputer.generate_samples(m=15).output_list
#       2 np.shape(imputations[-1])
#
# ~\anacondanew\lib\site-packages\MIDASpy\midas_base.py in generate_samples(self, m, verbose)
#     802
#     803     if not self.model_built:
# --> 804       raise AttributeError("The computation graph must be built before the model"\
#     805                            " can be trained")
#     806
#
# AttributeError: The computation graph must be built before the model can be trained

# %%
new_df=imputations[-1]
new_df.iloc[21,:]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\JABERS~1\AppData\Local\Temp/ipykernel_6756/73946934.py in <module>
# ----> 1 new_df=imputations[-1]
#       2 new_df.iloc[21,:]
#
# NameError: name 'imputations' is not defined

# %%
complete_df=pd.read_excel(r'C:\Users\Jaber Shahnawaz\Downloads\Original Datasets (1)\Original Datasets Without Labels\Sonar.xlsx', header=None,names=column_names)

# %%
new_df-complete_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\JABERS~1\AppData\Local\Temp/ipykernel_6756/2860186230.py in <module>
# ----> 1 new_df-complete_df
#
# NameError: name 'new_df' is not defined

# %% [markdown]
# Calculating NRMSE Value

# %%
def Sum_new(sum):
    summ=0
    for n in sum:
        summ=summ+n
    return (summ)

# %%
def Frobenius_norm(number):
    num=number
    abs_val=num.abs()
    power_abs=abs_val**2
    sum1=power_abs.sum()
    total_sum=Sum_new(sum1)
    return(math.sqrt(total_sum))

# %%
numerator=Frobenius_norm(new_df-complete_df)
numerator

# %%
denominator=Frobenius_norm(complete_df)
denominator

# %%
NRMS=numerator/denominator
NRMS

# %%
new_df.iloc[66,:]

# %%
imputations[-1]

# %%
imputations[-1].to_excel("Sonar_AE_1(imp).xlsx", index=False, header=False)
